# %%
var = 10

# %%
var
# Out:
# 10

# %%
# calaculate the perimeter and area of a square. 
length = 10
perimeter = 4 * length
area = length * length

# %%
perimeter
# Out:
# 40

# %%
area
# Out:
# 100

# %%
# if the value of the length of the square was not given and the user has to input a value, we use (take length has breadth because of running)
breadth = int(input("Insert value of length"))
print = (breadth)

# %%
perimet = 4 * breadth
arae = breadth * breadth

# %%
perimet
# Out:
# 80

# %%
arae
# Out:
# 400

# %%
# Exercise2- Arithmetic mean
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number:"))
num3 = int(input("Enter the third number:"))
num4 = int(input("Enter the fourth number:"))
# Out:
# Enter the first number: 10
# Enter the second number: 20
# Enter the third number: 30
# Enter the fourth number: 40

# %%
mean = (num1 + num2 + num3 + num4) / 4

# %%
mean
# Out:
# 25.0

# %%
#Exercise3 - Even or Odd

#Get value from the user
num = int(input("Enter a number:"))
